# %%
import pandas as pd
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# # ¿Tenemos datos no válidos?

# %%
def shape_and_null_values(file):
    print("str(file) shape: " + str(file.shape))
    print("Is null any?")
    print(str(file.isnull().any()))

# %%
trips = pd.read_csv('trip.csv', parse_dates=['start_date','end_date'], low_memory=False)
shape_and_null_values(trips)
# Out:
# str(file) shape: (669959, 11)
# Is null any?
# id                    False
# duration              False
# start_date            False
# start_station_name    False
# start_station_id      False
# end_date              False
# end_station_name      False
# end_station_id        False
# bike_id               False
# subscription_type     False
# zip_code               True
# dtype: bool

# %%
stations = pd.read_csv('station.csv')
shape_and_null_values(stations)
# Out:
# str(file) shape: (70, 7)
# Is null any?
# id                   False
# name                 False
# lat                  False
# long                 False
# dock_count           False
# city                 False
# installation_date    False
# dtype: bool

# %%
weather = pd.read_csv('weather.csv', parse_dates=['date'])
shape_and_null_values(weather)
# Out:
# str(file) shape: (3665, 24)
# Is null any?
# date                              False
# max_temperature_f                  True
# mean_temperature_f                 True
# min_temperature_f                  True
# max_dew_point_f                    True
# mean_dew_point_f                   True
# min_dew_point_f                    True
# max_humidity                       True
# mean_humidity                      True
# min_humidity                       True
# max_sea_level_pressure_inches      True
# mean_sea_level_pressure_inches     True
# min_sea_level_pressure_inches      True
# max_visibility_miles               True
# mean_visibility_miles              True
# min_visibility_miles               True
# max_wind_Speed_mph                 True
# mean_wind_speed_mph                True
# max_gust_speed_mph                 True
# precipitation_inches               True
# cloud_cover                        True
# events                             True
# wind_dir_degrees                   True
# zip_code                          False
# dtype: bool

# %%
iter_status = pd.read_csv('status.csv', iterator = True, chunksize = 100000)
iter_status.get_chunk().sample()
# Out:
#        station_id  bikes_available  docks_available                 time
# 90085           2               18                9  2013/11/02 10:13:01

# %%
iter_status.get_chunk().dtypes
# Out:
# station_id          int64
# bikes_available     int64
# docks_available     int64
# time               object
# dtype: object

# %% [markdown]
# # Cleanup

# %% [markdown]
# * Trips

# %%
# añadir columna day_of_week y separar la columa star_date y end_date en star_time y end_time con la hora
trips['day_of_week'] = trips['start_date'].dt.dayofweek

trips['start_time'] = trips.start_date.dt.time
trips['start_date'] = trips.start_date.dt.date

trips['end_time'] = trips.end_date.dt.time
trips['end_date'] = trips.end_date.dt.date

trips.sample()
# Out:
#             id  duration  start_date        start_station_name  \
# 439658  751083      1220  2015-05-03  Commercial at Montgomery
#
#         start_station_id    end_date                     end_station_name  \
# 439658                45  2015-05-03  Mechanics Plaza (Market at Battery)
#
#         end_station_id  bike_id subscription_type zip_code  day_of_week  \
# 439658              75      436          Customer      nil            6
#
#        start_time  end_time
# 439658   23:34:00  23:54:00

# %%
# start_date y end_date quedan de tipo datetime.date...
trips['start_date'] = pd.to_datetime(trips.start_date)
trips['end_date'] = pd.to_datetime(trips.end_date)

# %%
trips
# Out:
#             id  duration          start_date  \
# 0         4576        63 2013-08-29 14:13:00
# 1         4607        70 2013-08-29 14:42:00
# 21     2013-08-29 12:48:00             Redwood City Caltrain Station
# 22     2013-08-29 11:42:00                   San Francisco City Hall
# 23     2013-08-29 22:14:00                         Market at Sansome
# 24     2013-08-29 10:59:00                         Steuart at Market
# 25     2013-08-29 13:56:00                                 Japantown
# 26     2013-08-29 13:46:00                     Embarcadero at Folsom
# 27     2013-08-29 13:34:00                       San Salvador at 1st
# 28     2013-08-29 21:46:00                  South Van Ness at Market
# 29     2013-08-29 18:48:00                          Broadway at Main
# ...                    ...                                       ...
# 669929 2014-09-01 09:38:00                     San Jose Civic Center
# 669930 2014-09-01 16:05:00             Powell at Post (Union Square)
# 669931 2014-09-01 16:05:00             Powell at Post (Union Square)
# 669932 2014-09-01 09:29:00                         Market at Sansome
# 669933 2014-09-01 09:22:00                        Powell Street BART
# 669934 2014-09-01 09:05:00                             Howard at 2nd
# 669935 2014-09-01 11:00:00             Powell at Post (Union Square)
# 669936 2014-09-01 11:00:00             Powell at Post (Union Square)
# 669937 2014-09-01 08:54:00  San Francisco Caltrain (Townsend at 4th)
# 669938 2014-09-01 08:48:00                    Embarcadero at Sansome
# 669939 2014-09-01 08:57:00                    Embarcadero at Sansome
# 669940 2014-09-01 08:57:00                    Embarcadero at Sansome
# 669941 2014-09-01 08:52:00                          Davis at Jackson
# 669942 2014-09-01 08:36:00                    Embarcadero at Sansome
# 669943 2014-09-01 08:29:00                        Powell Street BART
# 669944 2014-09-01 10:12:00                         Market at Sansome
# 669945 2014-09-01 08:19:00                    Embarcadero at Sansome
# 669946 2014-09-01 08:14:00      Harry Bridges Plaza (Ferry Building)
# 669947 2014-09-01 12:27:00                   Mountain View City Hall
# 669948 2014-09-01 12:25:00                   Mountain View City Hall
# 669949 2014-09-01 07:35:00                     Embarcadero at Folsom
# 669950 2014-09-01 08:38:00                                 Japantown
# 669951 2014-09-01 07:05:00                         Market at Sansome
# 669952 2014-09-01 06:00:00                         Steuart at Market
# 669953 2014-09-01 05:03:00         Civic Center BART (7th at Market)
# 669954 2014-09-01 04:32:00                           Townsend at 7th
# 669955 2014-09-01 05:08:00  San Francisco Caltrain (Townsend at 4th)
# 669956 2014-09-01 00:14:00                             5th at Howard
# 669957 2014-09-01 00:15:00                             5th at Howard
# 669958 2014-09-01 00:15:00                             5th at Howard
#
#         end_station_id  bike_id subscription_type zip_code
# 0                   66      520        Subscriber    94127
# 1                   10      661        Subscriber    95138
# 2                   27       48        Subscriber    97214
# 3                   10       26        Subscriber    95060
# 4                   67      319        Subscriber    94103
# 5                   59      527        Subscriber    94109
# 6                    5      679        Subscriber    95112
# 7                    8      687        Subscriber    95112
# 8                   66      553        Subscriber    94103
# 9                   11      107        Subscriber    95060
# 10                  54      368        Subscriber    94109
# 11                   4       26        Subscriber    95112
# 12                  28      140        Subscriber    94041
# 13                  64      371        Subscriber    94122
# 14                  56      503        Subscriber    94109
# 15                  47      408        Subscriber    94117
# 16                  10       26        Subscriber    95060
# 17                  67      319        Subscriber    94103
# 18                  50      564        Subscriber    94115
# 19                  76      574        Subscriber    94115
# 20                  54      542        Subscriber    94105
# 21                  22      159        Subscriber    94061
# 22                  58      520        Subscriber    94110
# 23                  77      442        Subscriber    94115
# 24                  74      414          Customer    94117
# 25                   9      684        Subscriber    95112
# 26                  51      365        Subscriber    94109
# 27                   8      661        Subscriber    95112
# 28                  66      598        Subscriber    94115
# 29                  25      229        Subscriber    94041
# ...                ...      ...               ...      ...
# 669929               3      161        Subscriber     5112
# 669930              71      625          Customer    31100
# 669931              71      878          Customer    31100
# 669932              77      470        Subscriber    94103
# 669933              39      421        Subscriber    94107
# 669934              63      313        Subscriber    94133
# 669935              71      535          Customer      nil
# 669936              71      400          Customer      nil
# 669937              70      575        Subscriber    94080
# 669938              60      285          Customer        1
# 669939              60      317          Customer      nil
# 669940              60      590          Customer      nil
# 669941              42      462        Subscriber    94111
# 669942              60      566        Subscriber    94105
# 669943              39      578        Subscriber    94103
# 669944              77      357          Customer      nil
# 669945              60      375        Subscriber    94066
# 669946              50      496        Subscriber    94105
# 669947              27      140          Customer    94085
# 669948              27       57          Customer    94085
# 669949              51      496        Subscriber    94105
# 669950               9       56          Customer    95112
# 669951              77      617        Subscriber    94132
# 669952              74      561        Subscriber    94112
# 669953              72      292        Subscriber    94102
# 669954              65      335        Subscriber    94118
# 669955              70      259          Customer    44100
# 669956              57      466          Customer       32
# 669957              57      461          Customer       32
# 669958              57      318          Customer       32
#
# [669959 rows x 11 columns]

# %%
type(trips.zip_code[0])
# Out:
# str

# %%
print(trips[pd.to_numeric(trips.zip_code, errors='coerce').isnull()]['zip_code'])
# Out:
# 86        NaN
# 181       NaN
# 193       NaN
# 253       NaN
# 316       NaN
# 354       NaN
# 387       NaN
# 421       NaN
# 429       NaN
# 477       NaN
# 481       NaN
# 483       NaN
# 545       NaN
# 554       NaN
# 560       NaN
# 588       NaN
# 600       NaN
# 603       NaN
# 617       NaN
# 619       NaN
# 620       NaN
# 622       NaN
# 627       NaN
# 630       NaN
# 635       NaN
# 660       NaN
# 662       NaN
# 671       NaN
# 697       NaN
# 698       NaN
#          ...
# 669698    nil
# 669699    nil
# 669701    nil
# 669702    nil
# 669703    nil
# 669704    nil
# 669705    nil
# 669706    nil
# 669710    nil
# 669733    nil
# 669740    nil
# 669741    nil
# 669750    nil
# 669751    nil
# 669756    nil
# 669757    nil
# 669819    nil
# 669820    nil
# 669821    nil
# 669830    nil
# 669841    nil
# 669842    nil
# 669866    nil
# 669886    nil
# 669887    nil
# 669935    nil
# 669936    nil
# 669939    nil
# 669940    nil
# 669944    nil
# Name: zip_code, dtype: object

# %%
# para hacer join con weather es necesario que los zip_code sean int, dejando como NaN los datos no validos
trips.zip_code = pd.to_numeric(trips.zip_code, errors='coerce')
trips.dtypes
# Out:
# id                             int64
# duration                       int64
# start_date            datetime64[ns]
# start_station_name            object
# start_station_id               int64
# end_date              datetime64[ns]
# end_station_name              object
# end_station_id                 int64
# bike_id                        int64
# subscription_type             object
# zip_code                     float64
# day_of_week                    int64
# start_time                    object
# end_time                      object
# dtype: object

# %% [markdown]
# # Hay viajes que comienzan y terminan en la misma estacion? Cuanto duran?

# %%
trips.loc[trips.start_station_name == trips.end_station_name,['start_station_name','end_station_name','duration']]\
                .sort_values('duration')
# Out:
#                                    start_station_name  \
# 40000                                 Clay at Battery
# 406816                              Steuart at Market
# 213972                             Powell Street BART
# 456799                         Embarcadero at Sansome
# 55127            Harry Bridges Plaza (Ferry Building)
# 547555                            Golden Gate at Polk
# 509279                                2nd at Townsend
# 510302                                Beale at Market
# 2925          San Francisco Caltrain 2 (330 Townsend)
# 640817              Civic Center BART (7th at Market)
# 252114                                 Market at 10th
# 20568                                 Townsend at 7th
# 349254                                  Howard at 2nd
# 7296         San Francisco Caltrain (Townsend at 4th)
# 572681                              2nd at South Park
# 385850                                Spear at Folsom
# 3535                      Redwood City Public Library
# 160540                      Broadway St at Battery St
# 511423                             Powell Street BART
# 11545                                   Market at 4th
# 633879  Yerba Buena Center of the Arts (3rd @ Howard)
# 194364                             Powell Street BART
# 420035       San Francisco Caltrain (Townsend at 4th)
# 181744               Castro Street and El Camino Real
# 345157        San Francisco Caltrain 2 (330 Townsend)
# 124134                                2nd at Townsend
# 2887             Harry Bridges Plaza (Ferry Building)
# 98183                               2nd at South Park
# 531011        San Francisco Caltrain 2 (330 Townsend)
# 618094                              Market at Sansome
# ...                                               ...
# 185638                  Powell at Post (Union Square)
# 1461                               Powell Street BART
# 72116                        South Van Ness at Market
# 347156                         University and Emerson
# 347161                         University and Emerson
# 112395                California Ave Caltrain Station
# 10579           Rengstorff Avenue / California Street
# 25234                                       Japantown
# 537196                          San Jose Civic Center
# 80597                                   Market at 4th
# 80596                                   Market at 4th
# 662378                          San Jose Civic Center
# 214104          Rengstorff Avenue / California Street
# 658455                          San Jose Civic Center
# 26624           Rengstorff Avenue / California Street
# 484897              San Jose Diridon Caltrain Station
# 100174          Rengstorff Avenue / California Street
# 108144              Civic Center BART (7th at Market)
# 192978                        Mountain View City Hall
# 232372                   San Antonio Caltrain Station
# 192979                        Mountain View City Hall
# 568195                                 Market at 10th
# 619315                                 Market at 10th
# 640982                                      Japantown
# 517402                               San Pedro Square
# 119830                   San Antonio Caltrain Station
# 418295                               San Pedro Square
# 524518                          San Jose Civic Center
# 80510                          University and Emerson
# 371066                         University and Emerson
#
#                                      end_station_name  duration
# 40000                                 Clay at Battery        60
# 406816                              Steuart at Market        60
# 213972                             Powell Street BART        60
# 456799                         Embarcadero at Sansome        60
# 55127            Harry Bridges Plaza (Ferry Building)        60
# 547555                            Golden Gate at Polk        60
# 509279                                2nd at Townsend        60
# 510302                                Beale at Market        60
# 2925          San Francisco Caltrain 2 (330 Townsend)        60
# 640817              Civic Center BART (7th at Market)        60
# 252114                                 Market at 10th        60
# 20568                                 Townsend at 7th        60
# 349254                                  Howard at 2nd        60
# 7296         San Francisco Caltrain (Townsend at 4th)        60
# 572681                              2nd at South Park        60
# 385850                                Spear at Folsom        60
# 3535                      Redwood City Public Library        60
# 160540                      Broadway St at Battery St        60
# 511423                             Powell Street BART        60
# 11545                                   Market at 4th        60
# 633879  Yerba Buena Center of the Arts (3rd @ Howard)        60
# 194364                             Powell Street BART        60
# 420035       San Francisco Caltrain (Townsend at 4th)        60
# 181744               Castro Street and El Camino Real        60
# 345157        San Francisco Caltrain 2 (330 Townsend)        60
# 124134                                2nd at Townsend        60
# 2887             Harry Bridges Plaza (Ferry Building)        60
# 98183                               2nd at South Park        60
# 531011        San Francisco Caltrain 2 (330 Townsend)        60
# 618094                              Market at Sansome        60
# ...                                               ...       ...
# 185638                  Powell at Post (Union Square)    226108
# 1461                               Powell Street BART    241334
# 72116                        South Van Ness at Market    245831
# 347156                         University and Emerson    245875
# 347161                         University and Emerson    246067
# 112395                California Ave Caltrain Station    246487
# 10579           Rengstorff Avenue / California Street    246721
# 25234                                       Japantown    246966
# 537196                          San Jose Civic Center    250430
# 80597                                   Market at 4th    250989
# 80596                                   Market at 4th    250994
# 662378                          San Jose Civic Center    254700
# 214104          Rengstorff Avenue / California Street    257148
# 658455                          San Jose Civic Center    257233
# 26624           Rengstorff Avenue / California Street    272839
# 484897              San Jose Diridon Caltrain Station    289873
# 100174          Rengstorff Avenue / California Street    296045
# 108144              Civic Center BART (7th at Market)    303271
# 192978                        Mountain View City Hall    318236
# 232372                   San Antonio Caltrain Station    329715
# 192979                        Mountain View City Hall    348910
# 568195                                 Market at 10th    378964
# 619315                                 Market at 10th    457110
# 640982                                      Japantown    489435
# 517402                               San Pedro Square    505483
# 119830                   San Antonio Caltrain Station    586356
# 418295                               San Pedro Square    594550
# 524518                          San Jose Civic Center    602338
# 80510                          University and Emerson    722236
# 371066                         University and Emerson   1133540
#
# [23981 rows x 3 columns]

# %% [markdown]
# # Son viajes casuales?

# %%
casual_shorts_trips = pd.DataFrame({'count': trips.loc[trips.start_station_name == trips.end_station_name,\
        ['start_station_name','end_station_name','duration']]\
        .groupby(['start_station_name','end_station_name','duration']).size()}).reset_index()
casual_shorts_trips

# %%
casual_shorts_trips['count'].max()
# Out:
# 7

# %%
casual_shorts_trips[casual_shorts_trips['count'] == 7]
# Out:
#                         start_station_name  \
# 8554  Harry Bridges Plaza (Ferry Building)
#
#                           end_station_name  duration  count
# 8554  Harry Bridges Plaza (Ferry Building)        72      7

# %%
# los viajes casuales se repiten entre 1 y 7 veces, en dos años.
# Por lo que no aportan al objetivo de prediccion de la duracion de un viaje y se los elimina del set de datos.

trips = trips.loc[trips.start_station_name != trips.end_station_name,:]

# %% [markdown]
# * weather

# %%
weather
# Out:
#            date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0     8/29/2013               74.0                68.0               61.0
# 1     8/30/2013               78.0                69.0               60.0
# 2     8/31/2013               71.0                64.0               57.0
# 3      9/1/2013               74.0                66.0               58.0
# 4      9/2/2013               75.0                69.0               62.0
# 5      9/3/2013               73.0                67.0               60.0
# 6      9/4/2013               74.0                68.0               61.0
# 7      9/5/2013               72.0                66.0               60.0
# 8      9/6/2013               85.0                71.0               56.0
# 3659                17.0                     0          3.0     NaN
# 3660                29.0                     0          3.0     NaN
# 3661                30.0                     0          3.0     NaN
# 3662                26.0                     0          4.0     NaN
# 3663                29.0                     0          3.0     NaN
# 3664                24.0                     0          1.0     NaN
#
#       wind_dir_degrees zip_code
# 0                286.0    94107
# 1                291.0    94107
# 2                284.0    94107
# 3                284.0    94107
# 4                277.0    94107
# 5                276.0    94107
# 6                269.0    94107
# 7                270.0    94107
# 8                287.0    94107
# 9                305.0    94107
# 10               299.0    94107
# 11               303.0    94107
# 12               230.0    94107
# 13               219.0    94107
# 14               268.0    94107
# 15               271.0    94107
# 16               265.0    94107
# 17               276.0    94107
# 18               274.0    94107
# 19               270.0    94107
# 20               278.0    94107
# 21               297.0    94107
# 22               248.0    94107
# 23               218.0    94107
# 24               292.0    94107
# 25               294.0    94107
# 26               277.0    94107
# 27               281.0    94107
# 28               281.0    94107
# 29               279.0    94107
# ...                ...      ...
# 3635             318.0    95113
# 3636             293.0    95113
# 3637             289.0    95113
# 3638             298.0    95113
# 3639             305.0    95113
# 3640             317.0    95113
# 3641              50.0    95113
# 3642             308.0    95113
# 3643             329.0    95113
# 3644             309.0    95113
# 3645             310.0    95113
# 3646             317.0    95113
# 3647             315.0    95113
# 3648             288.0    95113
# 3649             289.0    95113
# 3650             295.0    95113
# 3651             283.0    95113
# 3652             341.0    95113
# 3653             318.0    95113
# 3654             225.0    95113
# 3655             123.0    95113
# 3656             312.0    95113
# 3657             305.0    95113
# 3658             301.0    95113
# 3659             303.0    95113
# 3660             313.0    95113
# 3661             307.0    95113
# 3662             312.0    95113
# 3663             291.0    95113
# 3664             308.0    95113
#
# [3665 rows x 24 columns]

# %%
weather.dtypes
# Out:
# date                              datetime64[ns]
# max_temperature_f                        float64
# mean_temperature_f                       float64
# min_temperature_f                        float64
# max_dew_point_f                          float64
# mean_dew_point_f                         float64
# min_dew_point_f                          float64
# max_humidity                             float64
# mean_humidity                            float64
# min_humidity                             float64
# max_sea_level_pressure_inches            float64
# mean_sea_level_pressure_inches           float64
# min_sea_level_pressure_inches            float64
# max_visibility_miles                     float64
# mean_visibility_miles                    float64
# min_visibility_miles                     float64
# max_wind_Speed_mph                       float64
# mean_wind_speed_mph                      float64
# max_gust_speed_mph                       float64
# precipitation_inches                      object
# cloud_cover                              float64
# events                                    object
# wind_dir_degrees                         float64
# zip_code                                   int64
# dtype: object

# %%
print( weather[pd.to_numeric(weather.precipitation_inches, errors='coerce').isnull()]['precipitation_inches'])
# "T" stands for "trace", used when precipitation has been detected, but it isn't sufficient to measure meaningfully.
# sin embargo cuando aparace T en un registro, el atributo event marca NaN y no "rain".(???)
# Out:
# 32      T
# 59      T
# 75      T
# 84      T
# 95      T
# 131     T
# 133     T
# 135     T
# 153     T
# 154     T
# 165     T
# 170     T
# 372     T
# 452     T
# 479     T
# 520     T
# 740     T
# 755     T
# 832     T
# 868     T
# 905     T
# 923     T
# 928     T
# 929     T
# 936     T
# 946     T
# 952     T
# 972     T
# 977     T
# 988     T
#        ..
# 3240    T
# 3246    T
# 3247    T
# 3272    T
# 3297    T
# 3317    T
# 3325    T
# 3344    T
# 3349    T
# 3372    T
# 3379    T
# 3403    T
# 3411    T
# 3448    T
# 3453    T
# 3454    T
# 3493    T
# 3502    T
# 3524    T
# 3535    T
# 3560    T
# 3563    T
# 3581    T
# 3603    T
# 3605    T
# 3611    T
# 3612    T
# 3621    T
# 3633    T
# 3652    T
# Name: precipitation_inches, dtype: object

# %% [markdown]
# # Cual es la estacion de donde salen mas viajes?

# %%
trips['start_station_name'].value_counts()[:5]
# Out:
# San Francisco Caltrain (Townsend at 4th)         49092
# San Francisco Caltrain 2 (330 Townsend)          33742
# Harry Bridges Plaza (Ferry Building)             32934
# Embarcadero at Sansome                           27713
# Temporary Transbay Terminal (Howard at Beale)    26089
# Name: start_station_name, dtype: int64

# %% [markdown]
# # Top 20 recorridos

# %%
routes_count = trips.loc[:,['id','start_station_name','end_station_name']]\
        .groupby(['start_station_name','end_station_name']).count()
routes_count.columns = ['trips_count']
routes_count = routes_count.reset_index().sort_values('trips_count', ascending=False)[:20]
routes_count
# Out:
#                                  start_station_name  \
# 1343        San Francisco Caltrain 2 (330 Townsend)
# 687            Harry Bridges Plaza (Ferry Building)
# 1713                                Townsend at 7th
# 87                                  2nd at Townsend
# 677            Harry Bridges Plaza (Ferry Building)
# 544                          Embarcadero at Sansome
# 503                           Embarcadero at Folsom
# 1617                              Steuart at Market
# 55                                2nd at South Park
# 1289       San Francisco Caltrain (Townsend at 4th)
# 1677  Temporary Transbay Terminal (Howard at Beale)
# 1306       San Francisco Caltrain (Townsend at 4th)
# 1714                                Townsend at 7th
# 1641                              Steuart at Market
# 1335        San Francisco Caltrain 2 (330 Townsend)
# 857                               Market at Sansome
# 529                          Embarcadero at Sansome
# 807                                  Market at 10th
# 1627                              Steuart at Market
# 700            Harry Bridges Plaza (Ferry Building)
#
#                                    end_station_name  trips_count
# 1343                                Townsend at 7th         6216
# 687                          Embarcadero at Sansome         6164
# 1713       San Francisco Caltrain (Townsend at 4th)         5041
# 87             Harry Bridges Plaza (Ferry Building)         4839
# 677                                 2nd at Townsend         4357
# 544                               Steuart at Market         4269
# 503        San Francisco Caltrain (Townsend at 4th)         3967
# 1617                                2nd at Townsend         3903
# 55                                Market at Sansome         3627
# 1289           Harry Bridges Plaza (Ferry Building)         3622
# 1677       San Francisco Caltrain (Townsend at 4th)         3526
# 1306  Temporary Transbay Terminal (Howard at Beale)         3510
# 1714        San Francisco Caltrain 2 (330 Townsend)         3495
# 1641       San Francisco Caltrain (Townsend at 4th)         3477
# 1335                             Powell Street BART         3438
# 857                               2nd at South Park         3427
# 529            Harry Bridges Plaza (Ferry Building)         3231
# 807        San Francisco Caltrain (Townsend at 4th)         3190
# 1627                         Embarcadero at Sansome         3116
# 700        San Francisco Caltrain (Townsend at 4th)         3033

# %% [markdown]
# # Cuanto dura la mayoria de los viajes?

# %%
duration_count = trips.loc[:,['duration','id']].groupby('duration').agg('count').reset_index()
duration_count.columns = ['duration','trip_count']
duration_count.plot.scatter('duration','trip_count')

# %%
# filtrando los que duran mas de 30 hs (?)
duration_count.loc[duration_count.duration < 10800].plot.scatter('duration','trip_count')

# %%
duration_count.loc[duration_count.duration < 2000].plot.scatter('duration','trip_count')

# %%
# la mayoria de los viajes duran entre 200 y 600 segundos
duration_count.loc[ ( 100 < duration_count.duration ) & ( duration_count.duration < 800)]\
            .plot.scatter('duration','trip_count')

# %%
# claramente existen outliers por lo que se los elimina del set de datos
# segun "http://www.bayareabikeshare.com/how-it-works" los viajes de mas de 30 min se cobran extra, por lo que se filtra 
# por duracion < 30 min y < 5 min.
trips = trips.loc[(trips.duration < 1800) & (trips.duration > 300)]

# %% [markdown]
# # Como varia la cantidad de viajes segun el dia de la semana?

# %%
trips.dtypes
# Out:
# id                             int64
# duration                       int64
# start_date            datetime64[ns]
# start_station_name            object
# start_station_id               int64
# end_date              datetime64[ns]
# end_station_name              object
# end_station_id                 int64
# bike_id                        int64
# subscription_type             object
# zip_code                      object
# day_of_week                    int64
# dtype: object

# %%
trips.sample()
# Out:
#             id  duration          start_date     start_station_name  \
# 572499  569961      1905 2014-12-08 15:52:00  Embarcadero at Folsom
#
#         start_station_id            end_date        end_station_name  \
# 572499                51 2014-12-08 16:23:00  Embarcadero at Sansome
#
#         end_station_id  bike_id subscription_type zip_code  day_of_week
# 572499              60      506          Customer    55960            0

# %%
plt.figure()

trips_by_day_count = trips['day_of_week'].value_counts().sort_index()
trips_by_day_count.index = ['Lunes','Martes','Miercoles','Jueves','Viernes','Sabado','Domingo']
plt.title('Total de viajes por dia de la semana')
plt.xlabel('Dia de la semana')
plt.ylabel('Cantidad de viajes')

trips_by_day_count.plot('bar');

# %% [markdown]
# ## ¿Qué tipos de subscripciones existen?

# %%
suscriptors = trips.groupby('subscription_type').agg('count')
suscriptors
# Out:
#                        id  duration  start_date  start_station_name  \
# subscription_type
# Customer           103213    103213      103213              103213
# Subscriber         566746    566746      566746              566746
#
#                    start_station_id  end_date  end_station_name  \
# subscription_type
# Customer                     103213    103213            103213
# Subscriber                   566746    566746            566746
#
#                    end_station_id  bike_id  zip_code  day_of_week
# subscription_type
# Customer                   103213   103213     96594       103213
# Subscriber                 566746   566746    566746       566746

# %% [markdown]
# # Los "Customers" tienden a estar mas los fines de semana?

# %%
customers_trips_by_day = trips.loc[trips['subscription_type'] == 'Customer',['day_of_week']]['day_of_week'].value_counts().sort_index()
customers_trips_by_day.index = ['Lunes','Martes','Miercoles','Jueves','Viernes','Sabado','Domingo']
customers_trips_by_day.plot('bar')

# %% [markdown]
# # Mean Duration Customers vs. Mean Duration Subscribers

# %%
duration_trip_by_subscription = pd.DataFrame({'mean_duration': trips.groupby(['subscription_type'])['duration'].mean(),\
                                'std_duration': trips.groupby(['subscription_type'])['duration'].std()})

duration_trip_by_subscription
# Out:
#                    mean_duration  std_duration
# subscription_type
# Customer             3068.506673  60301.122328
# Subscriber            578.621570   3368.785983

# %% [markdown]
# # En promedio, la duracion de los viajes en la semana es constante? Las personas van al trabajo en bicicleta?

# %%
def getNames(seriesOfNumbers):
    names = []
    days = ['Lunes','Martes','Miercoles','Jueves','Viernes','Sabado','Domingo']
    
    for numDay in seriesOfNumbers:
        names.append(days[numDay])
    return names

# %%
tripsByDayAndDuration = trips.loc[:,['day_of_week','duration']].sort_values('day_of_week')
tripsByDayAndDuration = tripsByDayAndDuration.groupby('day_of_week').mean().reset_index()
tripsByDayAndDuration['day_of_week'] = tripsByDayAndDuration[['day_of_week']].apply(lambda dates: getNames(dates))
tripsByDayAndDuration.plot.bar('day_of_week','duration',ylim=(0,1500), rot=0)
plt.title('Media de duracion de viajes')
plt.xlabel('Dia de la semana')
plt.ylabel('Duracion del viaje en segundos')

# %% [markdown]
# # Media de duracion de viajes de los 'subscribers'

# %%
subscriptors_trips = trips.loc[trips.subscription_type == 'Subscriber',['day_of_week','duration']]
subscriptors_trips = subscriptors_trips.groupby('day_of_week').mean().reset_index()
subscriptors_trips['day_of_week'] = subscriptors_trips[['day_of_week']].apply(lambda dates: getNames(dates))
subscriptors_trips.plot.bar('day_of_week','duration',ylim=(0,800), rot=0)
plt.title('Media de duracion de viaje de los \'Suscribers\'')
plt.xlabel('Dia de la semana')
plt.ylabel('Duracion del viaje (en segundos)')

# %% [markdown]
# # Media de duracion de los 'costumers'

# %%
customers_trips = trips.loc[trips.subscription_type == 'Customer',['day_of_week','duration']]
customers_trips = customers_trips.groupby('day_of_week').mean().reset_index()
customers_trips['day_of_week'] = customers_trips[['day_of_week']].apply(lambda dates: getNames(dates))
customers_trips.plot.bar('day_of_week','duration',ylim=(0,1500), rot=0)
plt.title('Media de duracion de viaje de los \'Customers\'')
plt.xlabel('Dia de la semana')
plt.ylabel('Duracion del viaje (en segundos)')

# %% [markdown]
# # Como es la variabilidad de la duracion de los viajes en la semana?

# %%
trips_by_day = trips.loc[:,['duration','day_of_week','id']]\
            .pivot_table(index='id', columns='day_of_week')
days = ['Lunes','Martes','Miercoles','Jueves','Viernes','Sabado','Domingo']
ax = trips_by_day.boxplot();
ax.set_xticklabels(days);

# %% [markdown]
# # Como varían los viajes en función de la hora?

# %%
trips['start_hour'] = trips.start_time.apply(lambda x: x.hour)

# %%
trips.shape
# Out:
# (509352, 15)

# %%
trips_by_hour = trips.loc[:,['start_hour','id']].groupby('start_hour').count()
trips_by_hour.columns = ['trips_count']
trips_by_hour.plot(kind='bar',rot=0);

# %% [markdown]
# # Como varía la duracion promedio de los viajes en función de la hora?

# %%
duration_by_hour = trips.loc[:,['start_hour','duration']].groupby('start_hour').mean()
duration_by_hour.plot(kind='bar',rot=0);

# %% [markdown]
# # Como varia la duracion promedio de los viajes en funcion del mes?

# %%
trips['month'] = trips.start_date.apply(lambda x: x.month)

# %%
trips_by_month = trips.loc[:,['month','duration']].groupby('month').mean()
trips_by_month.index = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']
trips_by_month.plot(kind='bar');
